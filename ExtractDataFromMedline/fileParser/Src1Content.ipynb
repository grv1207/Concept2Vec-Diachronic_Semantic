# %%
import pickle

# %%
with open('src1Data/10000000.bin','rb') as fin :
    dd = pickle.load(fin)

# %%
dd
# Out:
# {1965: [['5824933', 'UNITED STATES', ''],
#   ['5824934', 'UNITED STATES', ''],
#   ['5824935', 'UNITED STATES', ''],
#   ['5824936', 'UNITED STATES', ''],
#   ['5824937', 'UNITED STATES', ''],
#   ['5824938', 'UNITED STATES', ''],
#   ['5824939', 'UNITED STATES', ''],
#   ['5824940', 'UNITED STATES', ''],
#   ['5824941', 'UNITED STATES', ''],
#   ['5824942', 'UNITED STATES', ''],
#   ['5824943', 'UNITED STATES', ''],
#   ['5824946', 'NETHERLANDS', ''],
#   ['5824944', 'NETHERLANDS', ''],
#   ['5824945', 'NETHERLANDS', ''],
#   ['5824947', 'NETHERLANDS', ''],
#   ['5824948', 'NETHERLANDS', ''],
#   ['5889712', 'NETHERLANDS', ''],
#   ['5824949', 'NETHERLANDS', ''],
#   ['5889713', 'NETHERLANDS', ''],
#   ['5824950', 'NETHERLANDS', ''],
#   ['5824958', 'CANADA', ''],
#   ['5824959', 'CANADA', ''],
#   ['5824960', 'CANADA', ''],
#   ['5889716', 'CANADA', ''],
#   ['5824961', 'CANADA', ''],
#   ['5824962', 'CANADA', ''],
#   ['5824963', 'CANADA', ''],
#   ['5824964', 'CANADA', ''],
# ...

# %%
dd.keys()
# Out:
# dict_keys([1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983])

# %%
with open('src1Data/20000000.bin','rb') as fin :
    dd2 = pickle.load(fin)

# %%
dd2.keys()
# Out:
# dict_keys([1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983])

# %%
dd2
# Out:
# {1965: [['5824933', 'UNITED STATES', ''],
#   ['5824934', 'UNITED STATES', ''],
#   ['5824935', 'UNITED STATES', ''],
#   ['5824936', 'UNITED STATES', ''],
#   ['5824937', 'UNITED STATES', ''],
#   ['5824938', 'UNITED STATES', ''],
#   ['5824939', 'UNITED STATES', ''],
#   ['5824940', 'UNITED STATES', ''],
#   ['5824941', 'UNITED STATES', ''],
#   ['5824942', 'UNITED STATES', ''],
#   ['5824943', 'UNITED STATES', ''],
#   ['5212590', 'GERMANY, WEST', ''],
#   ['5212591', 'GERMANY, WEST', ''],
#   ['4283884', 'GERMANY, WEST', ''],
#   ['5212592', 'GERMANY, WEST', ''],
#   ['5212593', 'GERMANY, WEST', ''],
#   ['5212594', 'GERMANY, WEST', ''],
#   ['5212595', 'GERMANY, WEST', ''],
#   ['5824944', 'NETHERLANDS', ''],
#   ['5824945', 'NETHERLANDS', ''],
#   ['5824946', 'NETHERLANDS', ''],
#   ['5824947', 'NETHERLANDS', ''],
#   ['5824948', 'NETHERLANDS', ''],
#   ['5889712', 'NETHERLANDS', ''],
#   ['5824949', 'NETHERLANDS', ''],
#   ['5889713', 'NETHERLANDS', ''],
# ...

# %%
a = [1, 2, 4]
b = a[:]
b.insert(2, 3)

# %%
ll = ['','','q']

# %%
'|'.join(ll)
# Out:
# '||q'
